# %% [markdown]
# ## Generates a 60Hz sine wave from 0 to 255 (value levels)
#
# ### ploting the wave

# %%
import matplotlib.pyplot as plt
import numpy as np

f = 60.0	# Hz
v_min = 0   # steps
v_max = 255 # steps

t = np.linspace(0, 1/f, 51)
y = np.uint64((np.sin(2*np.pi*f*t) + 1) * (v_max-v_min) / 2)

plt.plot(t, y)	
plt.title('Sin wave (60Hz)')
plt.xlabel('time [s]')
plt.ylabel('amplitude [steps]')
plt.show()

# %% [markdown]
# ### generate the table to copy on Aixt

# %%
print('const y = [\n\tu8({}), '.format(y[0]), end='')
for i in range(1, len(y)-1): 
	if (i % 10) == 0 :
		print('\n\t', end='')
	print('{}, '.format(y[i]), end='')
print('\n]')
# Out:
# const y = [
# 	u8(127), 143, 159, 174, 188, 202, 214, 225, 235, 242,
# 	248, 252, 254, 254, 252, 248, 242, 235, 225, 214,
# 	202, 188, 174, 159, 143, 127, 111, 95, 80, 66,
# 	52, 40, 29, 19, 12, 6, 2, 0, 0, 2,
# 	6, 12, 19, 29, 40, 52, 66, 80, 95, 111,
# ]

# %% [markdown]
# ### sampling frequency

# %%
print('// sampling frequency: {}'.format((1/f)/50))
# Out:
# // sampling frequency: 0.0003333333333333333
